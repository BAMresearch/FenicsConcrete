# %% [markdown]
# # Linear regression example using Spike-Slab Prior
#
# The model equation is y = ax + b with a, b being the model parameters, while the
# likelihood model is based on a normal zero-mean additive model error distribution. The problem is solved via sampling using emcee.

# %%
import numpy as np
import matplotlib.pyplot as plt
import emcee
from scipy.stats import invgamma, halfcauchy, norm, bernoulli, uniform

# %%
def log_prior(theta):
    if theta[0] < 0.0 or theta[0] > 1.0:
        return -np.Inf
    return bernoulli.logpmf(0 if theta[0] < 0.5 else 1, p = 0.2)

""" def log_prior(theta):
    if theta[0] < 0.0 or theta[0] > 1.0:
        return -np.Inf
    elif theta[0] < 0.5:
        theta[0] = 0
        return bernoulli.logpmf(0, p = 0.2)
    elif theta[0] >= 0.5:
        theta[0] = 1
        return bernoulli.logpmf(1, p = 0.2) """
            
nwalkers = 2
ndim = 1
start_parameters = np.random.rand(nwalkers, ndim)
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_prior)
sampler.run_mcmc(start_parameters, 5000, progress=True)
# Out:
# 100%|██████████| 5000/5000 [00:01<00:00, 3146.26it/s]
# State([[0.37813003]
#  [0.17072287]], log_prob=[-0.22314355 -0.22314355], blobs=None, random_state=('MT19937', array([3091799997, 3480733788, 4005924982, 3998446630, 3841600198,
#        3598582375, 1038229332, 1618922272, 1626168388, 4140504290,
#        1059444225, 4211787647, 1920654897,  287462340,  647522092,
#        2396386857, 2752171419, 3177510445, 2381707856,  397009677,
#         607146868, 3155131131, 1248244075, 2650148511, 2219941060,
#        2470686875,  179698518, 2251611515, 4070725569, 4266671140,
#        3178590789, 2922908390, 2759954758,  457057901, 1720119931,
#        2577904933, 1508485904, 3884453263,  503080566, 3280880856,
#         847462329, 2869160164, 1442270807, 1792186315, 4003548826,
#        1744661497, 3888277147, 3650541342, 3606917584, 3725891114,
#         305569795, 2502566957,  280275641,  242384322,  697915293,
#        1152149353,  149216035, 4029416359, 2611215133, 2058101577,
#        3707553240,  574008936, 4004305488, 4086811151, 3838441415,
#        1381671008,  640686089, 4096859135, 4126046127,  779759784,
#         497500120,  654053885, 3620708425, 2512092957, 1904978172,
#        3229674313, 2753071806,  325228276,  893043800, 3589545083,
#        4025287783,  957821805, 3761617446, 2132704563, 2710668241,
#        3531380984, 2604327546, 2797749492, 3865282628, 2499186562,
#        3155132136,  840404447, 1342183765,  345996088,  606029821,
#        1323402961, 1534633684,  325757303, 1143904599, 1295068013,
#        2611097081, 1871371711, 2179943555, 2911786045, 4235642568,
#        3269250448, 3085368837, 1872072671,  605181091, 1603905868,
#        1877692220, 1438282158, 1872674746, 1324344408, 1120063549,
#         895832249, 4286385069, 3431821635, 1977960254,  280400576,
#        2989361713, 2144510708, 3329437191, 3534134466, 2290037617,
#        1716927061, 1275898332, 1015091921, 2788107539, 1885375933,
#        3321891591, 4293425430, 1572253003, 2426730378, 2051015127,
#        2666489493, 2662487739, 2944833094, 4203913869, 2000484908,
#        1629006178, 3840863961,  277478272, 3290820707, 1070084356,
#         544586479, 3071840610, 3600196824, 1446726900, 2890450637,
#        1555526962, 3372361801, 2332120158, 1516352050, 2852933723,
#         425201242,  513204747, 3215088761, 4083202763, 3310537297,
#        4059585685, 3999688664,  229108289,  514685764,  565498297,
#         423549152, 4024830400, 4074252669, 3928665283, 3864631519,
#         633530808,  792908580,  943507977, 2622565989, 3990309281,
#        4115438181, 3394530763, 3697852437, 1341394652,  597214983,
#        1904204558, 3624527237,   60631536, 3182156874, 4093010263,
#        3851531959, 1202401588, 2144911340, 1631411541, 2790355502,
#         135694324, 1930715812, 3251639929,  903815661, 3725596124,
#        1480220470,  426749131, 1268522682,  794610145, 3101552059,
#        3651015635, 1385891039, 1451485816, 3320611097, 3658130779,
#        1921675790, 1830367163,  175712518, 1351953158, 2693435143,
#        1834524856, 2327662934, 2359104176, 1084815812, 2908000653,
#        1147993605, 3541043450, 1544638683, 3652806949, 1967759012,
#        3299748563, 4018041901,  792123475,  250757500,  121277807,
#        1056981318,    8260784, 2741220192, 4004661798, 1263702357,
#        1823713878, 2906598750, 2357134153, 2357571269, 1418182527,
#        2450557341, 2395851470, 2013060353, 1233672485, 2140167584,
#         750654492, 3892697255, 2602858839, 3489185796, 2031338248,
#         337381205, 1063021268, 4035253301, 2941449908, 3374686077,
#        2739638336, 3554458946,  349955296, 3733452909, 1459451399,
#          33915706, 2502718668, 1146548148,   50164606, 1787461564,
#        1056079770, 3269754010, 3285432423, 3696527988,  901887088,
#        1732150235, 2698053625, 2097551938, 4238031800, 1042150331,
#        1237797155, 1563983516, 2088537955, 1721755495, 2917295610,
#        1402121308, 2753288992, 1842329168, 1420400579,  635617719,
#        4190912096, 1804761084,  443049034,   22133745,  845580681,
#        3285015242, 3018580027, 2233182847, 3219034122, 1528334264,
#        3047144714, 1726110538,   20344302,  813450898, 2762454446,
#        1665334615, 1028511838,  462267812, 3748330564, 2915210797,
#         640643281,  214419151,  306912064, 3524712373, 2763725966,
#         475251179, 1907051607, 2319228041, 3764507703, 1359394349,
#         186527317, 3300847729, 1056836218, 2212653986, 3770657616,
#        2039739995,  974232151, 1299521356, 1958990407, 3729396245,
#        3488560374, 4222863921, 3086234779, 3678976028, 1700416832,
#        2244622442, 4258441509, 2551340432, 4245173586, 3023118384,
#        2747433882, 1894956633, 2161078151, 4249979892, 1590305692,
#        1871996943,  986068332, 3852075149, 3655292161, 2975181436,
#         900124131, 1694785538, 3637189054, 3712523363, 1319538308,
#        3110824544, 2449217498, 2639134657, 3141239099,  926749656,
#        1632232846,  995083948, 3288036269, 3222336846, 4183233868,
#          46769848, 3044274227, 2353373450, 3526954003], dtype=uint32), 91, 0, 0.0))

# %% [markdown]
# Plotting the trace of the chain

# %%
samples = sampler.get_chain(discard=1000, thin=15, flat=True)
sum(samples > 0.5)/len(samples)
# Out:
# array([0.17105263])

# %%
fig, axes = plt.subplots(ndim, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["lmbda_a"] # Change the labels over here if changes in parameters are made in json file.
for i in range(ndim):
    ax = axes
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes.set_xlabel("step number")

# %% [markdown]
# Plotting the pair-plot of the chain.

# %%
flat_samples = sampler.get_chain(discard=500, thin=15, flat=True)
print(flat_samples.shape)
import corner
labels = ["lmbda_a"]  # Change the labels over here if changes in parameters are made in json file.
fig = corner.corner(
    flat_samples, labels=labels, truths=[1]
)
