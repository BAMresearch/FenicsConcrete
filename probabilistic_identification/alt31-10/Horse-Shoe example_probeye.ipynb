# %% [markdown]
# # Simple linear regression example
#
# The model equation is y = ax + b with a, b being the model parameters, while the
# likelihood model is based on a normal zero-mean additive model error distribution with
# the standard deviation to infer. The problem is solved via maximum likelihood estimation
# as well as via sampling using emcee.

# %% [markdown]
# First, let's import the required functions and classes for this example.

# %%
# third party imports
import numpy as np
import matplotlib.pyplot as plt

# local imports (problem definition)
from probeye.definition.inverse_problem import InverseProblem
from probeye.definition.forward_model import ForwardModelBase
from probeye.definition.distribution import Normal, Uniform, SpikeAndSlab, Bernoulli, RegularisedHorseShoe, HalfCauchy, InvGamma, HorseShoe
from probeye.definition.sensor import Sensor
from probeye.definition.likelihood_model import GaussianLikelihoodModel

# local imports (problem solving)
from probeye.inference.scipy.solver import MaxLikelihoodSolver
from probeye.inference.emcee.solver import EmceeSolver
from probeye.inference.dynesty.solver import DynestySolver

# local imports (inference data post-processing)
from probeye.postprocessing.sampling_plots import create_pair_plot
from probeye.postprocessing.sampling_plots import create_posterior_plot
from probeye.postprocessing.sampling_plots import create_trace_plot

# %% [markdown]
# We start by generating a synthetic data set from a known linear model to which we will
# add some noise. Afterwards, we will pretend to have forgotten the parameters of this
# ground-truth model and will instead try to recover them just from the data. The slope
# (a) and intercept (b) of the ground truth model are set to be:

# %%
# ground truth
a_true = 8
b_true = 10

# %% [markdown]
# Now, let's generate a few data points that we contaminate with a Gaussian error:

# %%
# settings for data generation
n_tests = 50
seed = 1
mean_noise = 0.0
std_noise = 1

# generate the data
np.random.seed(seed)
x_test = np.linspace(-4.0, 4.0, n_tests)
y_true = a_true * x_test ** 2  #a_true * x_test**2 #+ b_true * x_test + c_true #a_true * x_test**2 + 
y_test = y_true + np.random.normal(loc=mean_noise, scale=std_noise, size=n_tests)

# %% [markdown]
# Let's take a look at the data that we just generated:

# %%
plt.plot(x_test, y_test, "o", label="generated data points")
plt.plot(x_test, y_true, label="ground-truth model")
plt.plot(x_test, 0.08 * x_test ** 2 + 46 * x_test , label="ground-truth model") #1*np.exp(x_test)
plt.title("Data vs. ground truth")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %% [markdown]
# Until this point, we didn't use probeye at all, since we just generated some data. In
# a normal use case, we wouldn't have to generate our data of course. Instead, it would
# be provided to us, for example as the result of some test series. As the first step in
# any calibration problem, one needs to have a parameterized model (in probeye such a
# model is called 'forward model') of which one assumes that it is able to describe the
# data at hand. In this case, if we took a look at the blue data points in the plot
# above without knowing the orange line, we might expect a simple linear model. It is
# now our job to describe this model within the probeye-framework. This is done by
# defining our own specific model class:

# %%
class LinearModel(ForwardModelBase):
    def interface(self):
        self.parameters = ["a", "b"] #, "c"
        self.input_sensors = Sensor("x")
        self.output_sensors = Sensor("y", std_model="sigma")

    def response(self, inp: dict) -> dict:
        x = inp["x"]
        a = inp["a"]
        b = inp["b"]
        return {"y":  a * x ** 2 + b * x} #a * x ** 2 +

# %% [markdown]
# First, note that this model class is based on the probeye class 'ForwardModelBase'.
# While this is a requirement, the name of the class can be chosen freely. As you can
# see, this class has an 'interface' and a 'response' method. In the 'interface' method
# we define that our model has two parameters, 'a' and 'b', next to one input and one
# output sensors, called 'x' and 'y' respectively. Keeping this interface in mind,
# let's now take a look at the 'response' method. This method describes the actual
# forward model evaluation. The method takes one dictionary as an input and returns one
# dictionary as its output. The input dictionary 'inp' will have the keys 'a', 'b' and
# 'x' because of the definitions given in self.interface. Analogously, the returned
# dictionary must have the key 'y', because we defined an output sensor with the name
# 'y'. Note that the entire interface of the 'response' method is described by the
# 'interface' method. Parameters and input sensors will be contained in the 'inp'
# dictionary, while the output sensors must be contained in the returned dictionary.

# %% [markdown]
# After we now have defined our forward model, we can set up the inverse problem
# itself. This always begins by initializing an object form the InverseProblem-class,
# and adding all of the problem's parameters with priors that reflect our current best
# guesses of what the parameter's values might look like. Please check out the
# 'Components'-part of this documentation to get more information on the arguments seen
# below. However, most of the code should be self-explanatory.

# %% [markdown]
# As the next step, we need to add our experimental data the forward model and the
# likelihood model. Note that the order is important and should not be changed.

# %%
# initialize the problem (the print_header=False is only set to avoid the printout of
# the probeye header which is not helpful here)
problem = InverseProblem("Linear regression with Gaussian noise", print_header=False)

# add the problem's parameters
problem.add_parameter(
    "lmbda_a",
    #tex="$\lambda_a$",
    #info="Lambda of Slope of the graph",
    #domain="[0, +oo)",
    prior=HalfCauchy(loc=0, scale=1),
)

problem.add_parameter(
    "tau_a",
    #tex="$\lambda_a$",
    #info="Lambda of Slope of the graph",
    #domain="[0, +oo)",
    prior=HalfCauchy(loc=0, scale=0.1),
)

problem.add_parameter(
    "a",
    tex="$a$",
    #info="Slope of the graph",
    prior=HorseShoe(mean=0, lmbda="lmbda_a", tau="tau_a"),
)
#################################################################################################################

problem.add_parameter(
    "lmbda_b",
    #tex="$\lambda_a$",
    #info="Lambda of Slope of the graph",
    #domain="[0, +oo)",
    prior=HalfCauchy(loc=0, scale=1),
)

problem.add_parameter(
    "tau_b",
    #tex="$\lambda_a$",
    #info="Lambda of Slope of the graph",
    #domain="[0, +oo)",
    prior=HalfCauchy(loc=0, scale=0.1),
)

problem.add_parameter(
    "b",
    #tex="$a$",
    #info="Slope of the graph",
    prior=HorseShoe(mean=0, lmbda="lmbda_b", tau="tau_b"),
)

problem.add_parameter(
    "sigma",
    domain="(0, +oo)",
    tex=r"$\sigma$",
    info="Standard deviation, of zero-mean Gaussian noise model",
    #prior=Uniform(low=0.0, high=1.5),
    value = 1.0
)

# %%
# initialize the problem (the print_header=False is only set to avoid the printout of
# the probeye header which is not helpful here)
problem = InverseProblem("Linear regression with Gaussian noise", print_header=False)

# add the problem's parameters
problem.add_parameter(
    "lmbda_a",
    tex="$\lambda_a$",
    #info="Lambda of Slope of the graph",
    prior=Bernoulli(prob=0.5),
)
problem.add_parameter(
    "a",
    tex="$a$",
    #info="Slope of the graph",
    prior=SpikeAndSlab(mean=7, std=2.5, lmbda="lmbda_a"),
)
problem.add_parameter(
    "lmbda_b",
    tex="$\lambda_b$",
    #info="Lambda of Slope of the graph",
    prior=Bernoulli(prob=0.5),
)
problem.add_parameter(
    "b",
    #info="Intersection of graph with y-axis",
    tex="$b$",
    prior=SpikeAndSlab(mean=0, std=2, lmbda="lmbda_b"),
)
problem.add_parameter(
    "sigma",
    domain="(0, +oo)",
    tex=r"$\sigma$",
    info="Standard deviation, of zero-mean Gaussian noise model",
    #prior=Uniform(low=0.0, high=1.5),
    value = 1.0
)

# %%
# experimental data
problem.add_experiment(
    name="TestSeries_1",
    sensor_data={"x": x_test, "y": y_test},
)

# forward model
problem.add_forward_model(LinearModel("LinearModel"), experiments="TestSeries_1")

# likelihood model
problem.add_likelihood_model(
    GaussianLikelihoodModel(experiment_name="TestSeries_1", model_error="additive")
)

# %% [markdown]
# Now, our problem definition is complete, and we can take a look at its summary:

# %%
# print problem summary
problem.info(print_header=True)
# Out:
# 2023-10-04 11:17:08.652 | INFO     | # ================================================================================================ # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.653 | INFO     | #                                                                                                  # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.653 | INFO     | #                                            dP                                                    # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.654 | INFO     | #                                            88                                                    # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.655 | INFO     | #                  88d888b. 88d888b..d8888b. 88d888b. .d8888b. dP    dP .d8888b.                   # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.655 | INFO     | #                  88'  `88 88'     88'  `88 88'  `88 88ooood8 88    88 88ooood8                   # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.656 | INFO     | #                  88.  .88 88      88.  .88 88.  .88 88.      88.  .88 88.                        # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.657 | INFO     | #                  88Y888P' dP      `88888P' 88Y8888' `88888P' `8888P88 `88888P'                   # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.657 | INFO     | #                  88                                                .88                           # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.658 | INFO     | #                  dP                                            d8888P                            # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.658 | INFO     | #                                                                                                  # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.658 | INFO     | # ================================================================================================ # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.659 | INFO     | #                                                                                                  # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.659 | INFO     | #        Version 3.0.4 - A general framework for setting up parameter estimation problems.         # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.659 | INFO     | #                                                                                                  # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.660 | INFO     | # ================================================================================================ # | probeye.subroutines:print_probeye_header:620
# 2023-10-04 11:17:08.662 | INFO     |                                                                                                      | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.663 | INFO     | Problem summary: Linear regression with Gaussian noise                                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.663 | INFO     | ======================================================                                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.664 | INFO     |                                                                                                      | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.664 | INFO     | Forward models                                                                                       | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.664 | INFO     | ---------------------------------------------------------                                            | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.664 | INFO     |  Model name   | Global parameters   | Local parameters                                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.665 | INFO     | --------------+---------------------+--------------------                                            | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.665 | INFO     |  LinearModel  | a, b                | a, b                                                           | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.665 | INFO     |                                                                                                      | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.666 | INFO     | Priors                                                                                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.666 | INFO     | -------------------------------------------------------------------------------------------------    | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.666 | INFO     |  Prior name          | Global parameters                   | Local parameters                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.674 | INFO     | ---------------------+-------------------------------------+-------------------------------------    | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.675 | INFO     |  lmbda_a_half-cauchy | lmbda_a, loc_lmbda_a, scale_lmbda_a | lmbda_a, loc_lmbda_a, scale_lmbda_a     | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.675 | INFO     |  tau_a_half-cauchy   | tau_a, loc_tau_a, scale_tau_a       | tau_a, loc_tau_a, scale_tau_a           | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.677 | INFO     |  a_horse-shoe        | a, mean_a, lmbda_a, tau_a           | a, mean_a, lmbda_a, tau_a               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.678 | INFO     |  lmbda_b_half-cauchy | lmbda_b, loc_lmbda_b, scale_lmbda_b | lmbda_b, loc_lmbda_b, scale_lmbda_b     | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.678 | INFO     |  tau_b_half-cauchy   | tau_b, loc_tau_b, scale_tau_b       | tau_b, loc_tau_b, scale_tau_b           | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.679 | INFO     |  b_horse-shoe        | b, mean_b, lmbda_b, tau_b           | b, mean_b, lmbda_b, tau_b               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.679 | INFO     |                                                                                                      | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.679 | INFO     | Parameter overview                                                                                   | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.680 | INFO     | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.680 | INFO     |  Parameter type/role   | Parameter names                                                                                                                                        |   Count | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.680 | INFO     | -----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------+--------- | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.681 | INFO     |  Model parameters      | a, b                                                                                                                                                   |       2 | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.681 | INFO     |  Prior parameters      | loc_lmbda_a, scale_lmbda_a, lmbda_a, loc_tau_a, scale_tau_a, tau_a, mean_a, loc_lmbda_b, scale_lmbda_b, lmbda_b, loc_tau_b, scale_tau_b, tau_b, mean_b |      14 | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.681 | INFO     |  Likelihood parameters | sigma                                                                                                                                                  |       1 | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.682 | INFO     |  Const parameters      | loc_lmbda_a, scale_lmbda_a, loc_tau_a, scale_tau_a, mean_a, loc_lmbda_b, scale_lmbda_b, loc_tau_b, scale_tau_b, mean_b, sigma                          |      11 | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.682 | INFO     |  Latent parameters     | lmbda_a, tau_a, a, lmbda_b, tau_b, b                                                                                                                   |       6 | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.682 | INFO     |                                                                                                      | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.682 | INFO     | Parameter explanations                                                                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.683 | INFO     | ------------------------------------------------------------------------------                       | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.683 | INFO     |  Name          | Short explanation                                                                   | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.683 | INFO     | ---------------+--------------------------------------------------------------                       | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.683 | INFO     |  loc_lmbda_a   | Half-cauchy prior's parameter for latent parameter 'lmbda_a'                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.684 | INFO     |  scale_lmbda_a | Half-cauchy prior's parameter for latent parameter 'lmbda_a'                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.684 | INFO     |  lmbda_a       | No explanation provided                                                             | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.684 | INFO     |  loc_tau_a     | Half-cauchy prior's parameter for latent parameter 'tau_a'                          | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.684 | INFO     |  scale_tau_a   | Half-cauchy prior's parameter for latent parameter 'tau_a'                          | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.685 | INFO     |  tau_a         | No explanation provided                                                             | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.685 | INFO     |  mean_a        | Horse-shoe prior's parameter for latent parameter 'a'                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.685 | INFO     |  a             | No explanation provided                                                             | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.685 | INFO     |  loc_lmbda_b   | Half-cauchy prior's parameter for latent parameter 'lmbda_b'                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.686 | INFO     |  scale_lmbda_b | Half-cauchy prior's parameter for latent parameter 'lmbda_b'                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.686 | INFO     |  lmbda_b       | No explanation provided                                                             | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.686 | INFO     |  loc_tau_b     | Half-cauchy prior's parameter for latent parameter 'tau_b'                          | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.686 | INFO     |  scale_tau_b   | Half-cauchy prior's parameter for latent parameter 'tau_b'                          | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.686 | INFO     |  tau_b         | No explanation provided                                                             | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.687 | INFO     |  mean_b        | Horse-shoe prior's parameter for latent parameter 'b'                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.687 | INFO     |  b             | No explanation provided                                                             | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.687 | INFO     |  sigma         | Standard deviation, of zero-mean Gaussian noise model                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.688 | INFO     |                                                                                                      | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.688 | INFO     | Constant parameters                                                                                  | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.688 | INFO     | -------------------------                                                                            | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.688 | INFO     |  Name          |   Value                                                                             | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.689 | INFO     | ---------------+---------                                                                            | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.689 | INFO     |  loc_lmbda_a   |     0                                                                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.689 | INFO     |  scale_lmbda_a |     1                                                                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.690 | INFO     |  loc_tau_a     |     0                                                                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.690 | INFO     |  scale_tau_a   |     0.1                                                                             | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.690 | INFO     |  mean_a        |     0                                                                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.690 | INFO     |  loc_lmbda_b   |     0                                                                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.690 | INFO     |  scale_lmbda_b |     1                                                                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.691 | INFO     |  loc_tau_b     |     0                                                                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.691 | INFO     |  scale_tau_b   |     0.1                                                                             | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.691 | INFO     |  mean_b        |     0                                                                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.691 | INFO     |  sigma         |     1                                                                               | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.692 | INFO     |                                                                                                      | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.692 | INFO     | Theta interpretation                                                                                 | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.692 | INFO     | +---------------------------+                                                                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.692 | INFO     | |  Theta  |    Parameter    |                                                                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.693 | INFO     | |  index  |      name       |                                                                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.693 | INFO     | |---------------------------|                                                                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.693 | INFO     | |      0 --> lmbda_a        |                                                                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.693 | INFO     | |      1 --> tau_a          |                                                                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.694 | INFO     | |      2 --> a              |                                                                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.694 | INFO     | |      3 --> lmbda_b        |                                                                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.694 | INFO     | |      4 --> tau_b          |                                                                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.694 | INFO     | |      5 --> b              |                                                                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.695 | INFO     | +---------------------------+                                                                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.695 | INFO     |                                                                                                      | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.695 | INFO     | Added experiments                                                                                    | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.696 | INFO     | --------------------------------------------------                                                   | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.696 | INFO     |  Name         | Sensor values   | Forward model                                                      | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.696 | INFO     | --------------+-----------------+-----------------                                                   | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.697 | INFO     |  TestSeries_1 | x (50 elements) | LinearModel                                                        | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.697 | INFO     |               | y (50 elements) |                                                                    | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.697 | INFO     |                                                                                                      | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.697 | INFO     | Added likelihood models                                                                              | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.697 | INFO     | ---------------------------------------------------------------                                      | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.698 | INFO     |  Name         | Parameters   | Target sensors   | Experiment                                         | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.698 | INFO     | --------------+--------------+------------------+--------------                                      | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.698 | INFO     |  TestSeries_1 | sigma        | y                | TestSeries_1                                       | probeye.definition.inverse_problem:info:982
# 2023-10-04 11:17:08.699 | INFO     |                                                                                                      | probeye.definition.inverse_problem:info:982

# %% [markdown]
# After the problem definition comes the problem solution. There are different solver
# one can use, but we will just demonstrate how to use two of them: the scipy-solver,
# which merely provides a point estimate based on a maximum likelihood optimization, and
# the emcee solver, which is a MCMC-sampling solver. Let's begin with the scipy-solver:

# %% [markdown]
# All solver have in common that they are first initialized, and then execute a
# run-method, which returns its result data in the format of an arviz inference-data
# object (except for the scipy-solver). Let's now take a look at the emcee-solver.

# %%
# this is for using the emcee-solver (MCMC sampling)
emcee_solver = EmceeSolver(problem, show_progress=True)
inference_data = emcee_solver.run(n_steps=3300, n_initial_steps=1100, n_walkers=20)
posterior = emcee_solver.raw_results.get_chain()
# Out:
# 2023-10-04 11:17:11.836 | INFO     | Solving problem using emcee sampler with 1100 + 3300 samples and 20 walkers                          | probeye.inference.emcee.solver:run:178
# 2023-10-04 11:17:11.838 | INFO     | No additional options specified                                                                      | probeye.inference.emcee.solver:run:186
# 100%|██████████| 1100/1100 [00:09<00:00, 121.01it/s]
# 100%|██████████| 3300/3300 [00:26<00:00, 125.47it/s]
# 2023-10-04 11:17:47.271 | INFO     | Sampling of the posterior distribution completed: 3300 steps and 20 walkers.                         | probeye.inference.emcee.solver:run:280
# 2023-10-04 11:17:47.272 | INFO     | Total run-time (including initial sampling): 35s.                                                    | probeye.inference.emcee.solver:run:284
# 2023-10-04 11:17:47.272 | INFO     |                                                                                                      | probeye.inference.emcee.solver:run:285
# 2023-10-04 11:17:47.272 | INFO     | Summary of sampling results (emcee)                                                                  | probeye.inference.emcee.solver:run:286
# 2023-10-04 11:17:47.287 | INFO     |            mean    median     sd     5%    95%                                                       | probeye.inference.emcee.solver:emcee_summary:137
# 2023-10-04 11:17:47.288 | INFO     | -------  ------  --------  -----  -----  -----                                                       | probeye.inference.emcee.solver:emcee_summary:137
# 2023-10-04 11:17:47.288 | INFO     | lmbda_a   20.76      9.55  32.24   1.69  79.95                                                       | probeye.inference.emcee.solver:emcee_summary:137
# 2023-10-04 11:17:47.289 | INFO     | tau_a      0.53      0.33   0.59   0.05   1.64                                                       | probeye.inference.emcee.solver:emcee_summary:137
# 2023-10-04 11:17:47.290 | INFO     | a          8.01      8.01   0.02   7.98   8.04                                                       | probeye.inference.emcee.solver:emcee_summary:137
# 2023-10-04 11:17:47.290 | INFO     | lmbda_b    6.09      0.92  30.82   0.06  11.93                                                       | probeye.inference.emcee.solver:emcee_summary:137
# 2023-10-04 11:17:47.291 | INFO     | tau_b      0.14      0.09   0.15   0.01   0.45                                                       | probeye.inference.emcee.solver:emcee_summary:137
# 2023-10-04 11:17:47.291 | INFO     | b          0.01      0.00   0.03  -0.01   0.08                                                       | probeye.inference.emcee.solver:emcee_summary:137
# 2023-10-04 11:17:47.292 | INFO     |                                                                                                      | probeye.inference.emcee.solver:run:292

# %% [markdown]
# Finally, we want to plot the results we obtained. To that end, probeye provides some
# post-processing routines, which are mostly based on the arviz-plotting routines.

# %%
# this is optional, since in most cases we don't know the ground truth
true_values = {"a": a_true, "b": 0, "lmbda_a": 0, "tau_a": 0, "lmbda_b": 0, "tau_b": 0}

#true_values = {"a": 0, "b": b_true, "lmbda_a": 0, "sigma": std_noise}

# this is an overview plot that allows to visualize correlations
pair_plot_array = create_pair_plot(
    inference_data, 
    emcee_solver.problem,
    true_values=true_values,
    focus_on_posterior=True,
    show_legends=True,
    title="Sampling results from emcee-Solver (pair plot)",
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/dtyagi/FenicsConcrete/probabilistic_identification/Horse-Shoe example_probeye.ipynb Cell 24 line 7
#       <a href='vscode-notebook-cell:/home/dtyagi/FenicsConcrete/probabilistic_identification/Horse-Shoe%20example_probeye.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> true_values = {"a": a_true, "b": 0, "lmbda_a": 0, "tau_a": 0, "lmbda_b": 0, "tau_b": 0}
#       <a href='vscode-notebook-cell:/home/dtyagi/FenicsConcrete/probabilistic_identification/Horse-Shoe%20example_probeye.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a> #true_values = {"a": 0, "b": b_true, "lmbda_a": 0, "sigma": std_noise}
#       <a href='vscode-notebook-cell:/home/dtyagi/FenicsConcrete/probabilistic_identification/Horse-Shoe%20example_probeye.ipynb#X32sZmlsZQ%3D%3D?line=4'>5</a>
#       <a href='vscode-notebook-cell:/home/dtyagi/FenicsConcrete/probabilistic_identification/Horse-Shoe%20example_probeye.ipynb#X32sZmlsZQ%3D%3D?line=5'>6</a> # this is an overview plot that allows to visualize correlations
# ----> <a href='vscode-notebook-cell:/home/dtyagi/FenicsConcrete/probabilistic_identification/Horse-Shoe%20example_probeye.ipynb#X32sZmlsZQ%3D%3D?line=6'>7</a> pair_plot_array = create_pair_plot(
#       <a href='vscode-notebook-cell:/home/dtyagi/FenicsConcrete/probabilistic_identification/Horse-Shoe%20example_probeye.ipynb#X32sZmlsZQ%3D%3D?line=7'>8</a>     inference_data,
#       <a href='vscode-notebook-cell:/home/dtyagi/FenicsConcrete/probabilistic_identification/Horse-Shoe%20example_probeye.ipynb#X32sZmlsZQ%3D%3D?line=8'>9</a>     emcee_solver.problem,
#      <a href='vscode-notebook-cell:/home/dtyagi/FenicsConcrete/probabilistic_identification/Horse-Shoe%20example_probeye.ipynb#X32sZmlsZQ%3D%3D?line=9'>10</a>     true_values=true_values,
#      <a href='vscode-notebook-cell:/home/dtyagi/FenicsConcrete/probabilistic_identification/Horse-Shoe%20example_probeye.ipynb#X32sZmlsZQ%3D%3D?line=10'>11</a>     focus_on_posterior=True,
#      <a href='vscode-notebook-cell:/home/dtyagi/FenicsConcrete/probabilistic_identification/Horse-Shoe%20example_probeye.ipynb#X32sZmlsZQ%3D%3D?line=11'>12</a>     show_legends=True,
#      <a href='vscode-notebook-cell:/home/dtyagi/FenicsConcrete/probabilistic_identification/Horse-Shoe%20example_probeye.ipynb#X32sZmlsZQ%3D%3D?line=12'>13</a>     title="Sampling results from emcee-Solver (pair plot)",
#      <a href='vscode-notebook-cell:/home/dtyagi/FenicsConcrete/probabilistic_identification/Horse-Shoe%20example_probeye.ipynb#X32sZmlsZQ%3D%3D?line=13'>14</a> )
#
# File ~/anaconda3/envs/fenicsxclone/lib/python3.10/site-packages/probeye/postprocessing/sampling_plots.py:230, in create_pair_plot(inference_data, problem, plot_with, plot_priors, focus_on_posterior, kind, figsize, inches_per_row, inches_per_col, textsize, title_size, title, true_values, show_legends, show, **kwargs)
#     228     posterior_handle, posterior_label = [], []
#     229 rotate = True if problem.n_latent_prms_dim == 2 and i == 1 else False
# --> 230 problem.parameters[prm_name].prior.plot(
#     231     axs[i, i],
#     232     problem.parameters,
#     233     x=x,
#     234     rotate=rotate,
#     235     label="prior",
#     236 )
#     237 # don't use the histogram bin ticks when the prior is also plotted
#     238 if histograms_on_diagonal and not focus_on_posterior:
#
# File ~/anaconda3/envs/fenicsxclone/lib/python3.10/site-packages/probeye/inference/scipy/priors.py:79, in Prior.plot(self, ax, prms, x, n_points, color, rotate, label)
#      64 def plot(
#      65     self,
#      66     ax: "plt.Axes",
#    (...)
#      72     label: str = "pdf",
#      73 ):
#      74     """
#      75     Plots the prior-pdf to a given axis object using the prior's 'dist'-object.
#      76     For more information on the arguments of this method checkout the reference
#      77     method :func:`~probeye.definition.distribution.ProbabilityDistribution.plot`.
#      78     """
# ---> 79     self.dist.plot(self.ref_prm, ax, prms, x, n_points, color, rotate, label)
#
# File ~/anaconda3/envs/fenicsxclone/lib/python3.10/site-packages/probeye/inference/scipy/distributions.py:1431, in HorseShoeDistribution.plot(self, primary_var, ax, parameters, x, n_points, color, rotate, label)
#    1429         right = max(x)
#    1430 prms[primary_var] = x
# -> 1431 y = self(primary_var, prms, "pdf")
#    1432 margin = 0.025 * abs(right - left)
#    1433 adjusted_left = left - margin
#
# File ~/anaconda3/envs/fenicsxclone/lib/python3.10/site-packages/probeye/inference/scipy/distributions.py:1398, in HorseShoeDistribution.__call__(self, primary_var, prms, method, use_primary_var, **kwargs)
#    1396 if use_primary_var:
#    1397     x = prms[primary_var]
# -> 1398     return fun(x, loc=mean, scale= np.square(lmbda*tau), **kwargs)
#    1399 else:
#    1400     return fun(loc=mean, scale= np.square(lmbda*tau), **kwargs)
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'NoneType'

# %%
# this is a posterior plot, without including priors
post_plot_array = create_posterior_plot(
    inference_data,
    emcee_solver.problem,
    true_values=true_values,
    title="Sampling results from emcee-Solver (posterior plot)",
)

# %%
# trace plots are used to check for "healthy" sampling
trace_plot_array = create_trace_plot(
    inference_data,
    emcee_solver.problem,
    title="Sampling results from emcee-Solver (trace plot)",
)

# %%
plt.plot(x_test, y_test, "o", label="generated data points")
plt.plot(x_test, y_true, label="ground-truth model")
plt.plot(x_test, -0.9*np.exp(-x_test) -10 , label="ground-truth model")
plt.title("Data vs. ground truth")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()
