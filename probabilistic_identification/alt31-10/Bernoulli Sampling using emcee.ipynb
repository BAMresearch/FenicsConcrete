# %% [markdown]
# # Linear regression example using Spike-Slab Prior
#
# The model equation is y = ax + b with a, b being the model parameters, while the
# likelihood model is based on a normal zero-mean additive model error distribution. The problem is solved via sampling using emcee.

# %%
import numpy as np
import matplotlib.pyplot as plt
import emcee
from scipy.stats import invgamma, halfcauchy, norm, bernoulli, uniform

# %%
def log_prior(theta):
    if theta[0] < 0.0 or theta[0] > 1.0:
        return -np.Inf
    return bernoulli.logpmf(0 if theta[0] < 0.5 else 1, p = 0.2)

""" def log_prior(theta):
    if theta[0] < 0.0 or theta[0] > 1.0:
        return -np.Inf
    elif theta[0] < 0.5:
        theta[0] = 0
        return bernoulli.logpmf(0, p = 0.2)
    elif theta[0] >= 0.5:
        theta[0] = 1
        return bernoulli.logpmf(1, p = 0.2) """
            
nwalkers = 2
ndim = 1
start_parameters = np.random.rand(nwalkers, ndim)
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_prior)
sampler.run_mcmc(start_parameters, 5000, progress=True)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# 100%|██████████| 5000/5000 [00:01<00:00, 3137.46it/s]
# State([[0.25580334]
#  [0.79779069]], log_prob=[-0.22314355 -1.60943791], blobs=None, random_state=('MT19937', array([ 511415355, 2976889677,  691957307, 2562479105, 1029262931,
#        2078597897, 4171473786,  133695670, 1457771619, 1152820194,
#        1206562975, 2457282709,   39838820,  171601938, 3665507867,
#         895036996, 2411484048, 3615228695,   40791962, 2889811943,
#        2343972694, 1068386204, 2880080642,  753670122, 3129724787,
#         650397100,  289981738,  333740544, 3796513899, 1320463754,
#        2298522561,  278228596, 3689952013, 3360586661, 1070688814,
#        2014230620, 3685019848, 2828668468, 1039753614, 3806630384,
#        1320851311, 1619371235, 3864147487, 1473589626, 3326832103,
#         431328244, 1786498715,  309233622,  567381042, 1410276307,
#         876133221, 1366744474, 3428543899, 2812428033, 3718393368,
#        3018675732, 3200479158, 4175083794, 3917272861, 3621382036,
#        1149812343, 2729342129, 3052457255, 4201390690, 3373871837,
#        3660256001, 1587695430, 1405630792,  710368117, 3046549966,
#          79324659, 3536523332,  361404616, 2392788238, 2648230800,
#        4158307857,  520385382,  289484570, 2628029051, 2143432807,
#        3085201288, 1669156182, 2101542415, 3679397680, 3517984599,
#         292384661,  618379656, 1245472832, 3622698177,  858909221,
#         893172084, 1300300842, 4191596185,  640747691,  951344242,
#         861407016,  641179064, 1351890728, 3474036948, 3600849013,
#        4217031942, 3837800679, 1403219599, 3387448427, 1928384357,
#        1709926556, 1791242127, 3186598633, 3984688533, 2270290893,
#         254417539, 2686913326, 2881301726,  543355615,  155583123,
#        3701924130, 2626574208,  692908224, 2330579995, 3844372291,
#        2207123329, 1672466110,  248323435, 3027968764, 2966878508,
#        3204839148, 3915646203, 2902489571, 3974007061, 3244152780,
#         198955844, 1156206653, 3673064999, 4172195293,  511277082,
#        1794294658, 3751437026, 1000608054, 2466681210, 2903977826,
#        3400086826, 1810375101, 2838064531,  506887187, 2674528987,
#        4090644724, 1623687595,  791287141,  859177521, 1932776850,
#         840377945, 2211021522, 3701407413,   63193398, 1896117026,
#        4273487306, 3018779821, 2046092335,  863591647, 1387689059,
#        1889037019, 1676960415, 3034393115, 1330240191, 1633357416,
#        3655111066, 2029910154,  134023828, 3416977685,  152814120,
#        4291051697, 1202393366, 1175227331, 3149022544,  496058979,
#        1570352874,  949317878,  165950364,  482256036, 3663769435,
#         542190587,  514614123, 3295973824, 1505738347,  714488801,
#        3860666482, 3880006929, 3944500482, 2074141109, 3181663024,
#         323700602,   21806223, 3636197865,  838837290, 1568457501,
#         987285958, 3802036925, 1473077667,  390672589, 2093941675,
#         130819827, 1390874323, 1713456856,  433949815, 1302388689,
#         671697128,  440317440, 3920178363, 2302517583, 4168599550,
#        1265804856, 4087901027, 3267851672, 2823826868, 1064702081,
#        2839815998,  467610305, 2824229071, 3624761216, 2660922204,
#        2023793554, 2806482928, 2968953381, 2189190630, 3499694410,
#        3420800596, 3999559877,  766995163, 1075304860, 1757242535,
#        3975297573, 2731954314, 1621969194, 3809916642, 1877480108,
#        2529088057,  826868650, 1558794875, 3899302001,  355310214,
#        3188855330, 3931640883, 4118145991, 4248382974, 4062937318,
#        2543507407, 1266046005,  787295239, 1546806744, 1371138809,
#        4113104231, 2359665688, 1674456521, 3004768345, 2980595264,
#        3822997577, 2163594114, 3764941226, 1639310031, 1800648162,
#        1964509453, 2229897200, 2158296453, 2521769309, 2972009629,
#        2373148437, 3549512128, 3580026694, 1907891648, 3643647120,
#        4112158157,  964760852, 1534534138, 2346293789, 4156777045,
#        3300534544, 3721157246,  858176909,   95547729, 2490914163,
#         812052081, 3473230652,  410982030,  114175411,  342041790,
#        1855555564, 2202302155, 3940066596, 2854518330, 1357203088,
#        3559583906, 4131029042,  569496663, 3324494543, 4214004793,
#         330444831, 3810531989, 2427441168, 2471450038,  585510549,
#         798210309, 3004348140, 3091557342, 1494078719, 2904344929,
#        3438706781,  705177601, 3496503983, 4175857854, 3068980271,
#        3600237906, 1814914834, 1865057866, 1452723315, 3365947289,
#        3555874132, 2668806891,  930627764, 1137604376, 1533938381,
#        2871239564, 3949208933,  289314044, 1750278927,  447926625,
#        2437941239, 2835750641, 3779685734, 3357552664, 1531516865,
#        4154731158,  732100546, 2130534665, 3589534178, 2476259132,
#        2043338737, 2633173113, 1739720150, 3096907977, 2401337976,
#        3283053394, 1164801850, 4085080147,  407478893,  483176193,
#        2281140877, 2154820470, 4179018889, 1677755055, 1514053154,
#         845423486,  306873097, 3103085324, 1156721611, 3322562111,
#        1353852865, 1000161518, 3403068962,  956991745,  491882421,
#        4205125848, 3480403259,  734742863, 1032337590,  474024268,
#        2440840310,  532855153, 1417681613, 3107934071], dtype=uint32), 91, 0, 0.0))

# %% [markdown]
# Plotting the trace of the chain

# %%
samples = sampler.get_chain(discard=1000, thin=15, flat=True)
sum(samples > 0.5)/len(samples)
# Out:
# array([0.2424812])

# %%
fig, axes = plt.subplots(ndim, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["lmbda_a"] # Change the labels over here if changes in parameters are made in json file.
for i in range(ndim):
    ax = axes
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes.set_xlabel("step number")

# %% [markdown]
# Plotting the pair-plot of the chain.

# %%
flat_samples = sampler.get_chain(discard=500, thin=15, flat=True)
print(flat_samples.shape)
import corner
labels = ["lmbda_a"]  # Change the labels over here if changes in parameters are made in json file.
fig = corner.corner(
    flat_samples, labels=labels, truths=[1]
)
